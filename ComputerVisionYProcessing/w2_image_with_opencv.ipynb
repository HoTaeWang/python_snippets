# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("11110-megami_jun.webp")
print(type(img))
print(img.size)
print(img.shape)
# cv2.imshow('megami jun', img)
# cv2.waitkey(0)
# cv2.destoryAllWindows()

plt.figure(figsize = (10,10))
plt.imshow(img)
plt.show()
# Out:
# <class 'numpy.ndarray'>
# 1723692
# (758, 758, 3)

# %%
new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(new_img)
plt.show()

# %%
cv2.imwrite("jun_megami.jpg", img)
# Out:
# True

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_img.shape
# Out:
# (758, 758)

# %%
plt.figure(figsize=(10,10))
plt.imshow(gray_img, cmap='gray')
plt.show()
