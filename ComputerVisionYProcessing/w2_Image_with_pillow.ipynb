# %%
from PIL import Image
from PIL import ImageOps
import numpy as np
import matplotlib.pyplot as plt

my_image = Image.open("11110-megami_jun.webp")
type(my_image)
my_image.show()

image_gray = ImageOps.grayscale(my_image)
image_gray.mode
image_gray

#  PIL ==> Numpy  1)asarray()  2) copy of array
array = np.asarray(my_image)
print(type(array))

array2 = np.array(my_image)
print(array2.shape)
print(array)
# Out:
# <class 'numpy.ndarray'>
# (758, 758, 3)
# [[[ 42  19   6]
#   [ 42  19   6]
#   [ 42  19   6]
#   ...
#   [ 36  14   6]
#   [ 36  14   6]
#   [ 36  14   6]]
#
#  [[ 42  19   6]
#   [ 42  19   6]
#   [ 42  19   6]
#   ...
#   [ 36  14   6]
#   [ 36  14   6]
#   [ 36  14   6]]
#
#  [[ 42  19   6]
#   [ 42  19   6]
#   [ 42  19   6]
#   ...
#   [ 36  14   6]
#   [ 36  14   6]
#   [ 36  14   6]]
#
#  ...
#
#  [[100  78  74]
#   [104  82  78]
#   [110  88  84]
#   ...
#   [ 12  11  14]
#   [ 12  11  14]
#   [ 12  11  14]]
#
#  [[102  80  76]
#   [108  86  82]
#   [113  90  87]
#   ...
#   [ 13  10  14]
#   [ 12  11  14]
#   [ 12  11  14]]
#
#  [[104  82  78]
#   [110  88  84]
#   [115  93  89]
#   ...
#   [ 12   9  12]
#   [ 10  10  12]
#   [ 10  10  12]]]

# %%
array[0,0]
# Out:
# array([42, 19,  6], dtype=uint8)

# %%
array.min()
# Out:
# 0

# %%
array.max()
# Out:
# 255

# %%
plt.figure(figsize=(10, 10))
plt.imshow(array)
plt.show()
