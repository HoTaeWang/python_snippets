# %%
from PIL import Image
import matplotlib.pyplot as plt

def concate_image_by_h(img1, img2):
    dst = Image.new('RGB', (img1.width+img2.width, img1.height))
    dst.paste(img1, (0, 0))
    dst.paste(img2, (img1.width, 0))
    return dst

img = Image.open("11110-megami_jun.webp")
print(" Type of Image : ", type(img))
plt.figure(figsize=(6, 6))
plt.imshow(img)
print(" Size of Image : ", img.size)

red, green, blue = img.split()
concate_image_by_h(red, green)
# Out:
#  Type of Image :  <class 'PIL.WebPImagePlugin.WebPImageFile'>
#  Size of Image :  (758, 758)
# <PIL.Image.Image image mode=RGB size=1516x758>
