# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# %%
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 90],
                             [96, 98, 100],
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152],
                             [185],
                             [180],
                             [196],
                             [142]])
dataset = TensorDataset(x_train, y_train)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = nn.Linear(3, 1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs+1):
  for batch_idx, samples in enumerate(dataloader):
    x_train, y_train = samples
    print(x_train, y_train, sep='\n')
    prediction = model(x_train)
    cost = F.mse_loss(prediction, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {}/{} Cost: {}'.format(epoch, nb_epochs, cost.item()))
# Out:
# tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]])
# tensor([[196.],
#         [180.]])
# Epoch 0/20 Cost: 68963.328125
# tensor([[93., 88., 93.],
#         [73., 80., 75.]])
# tensor([[185.],
#         [152.]])
# Epoch 0/20 Cost: 12435.0283203125
# tensor([[73., 66., 70.]])
# tensor([[142.]])
# Epoch 0/20 Cost: 3078.184814453125
# tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]])
# tensor([[185.],
#         [196.]])
# Epoch 1/20 Cost: 2477.6416015625
# tensor([[89., 91., 90.],
#         [73., 66., 70.]])
# tensor([[180.],
#         [142.]])
# Epoch 1/20 Cost: 418.17242431640625
# tensor([[73., 80., 75.]])
# tensor([[152.]])
# Epoch 1/20 Cost: 111.6463623046875
# tensor([[73., 80., 75.],
#         [93., 88., 93.]])
# tensor([[152.],
#         [185.]])
# Epoch 2/20 Cost: 76.8507308959961
# tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]])
# tensor([[196.],
#         [180.]])
# Epoch 2/20 Cost: 15.137161254882812
# tensor([[73., 66., 70.]])
# tensor([[142.]])
# Epoch 2/20 Cost: 23.00473976135254
# tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]])
# tensor([[196.],
#         [152.]])
# Epoch 3/20 Cost: 0.17928610742092133
# tensor([[89., 91., 90.],
#         [73., 66., 70.]])
# tensor([[180.],
#         [142.]])
# Epoch 3/20 Cost: 5.973115921020508
# tensor([[93., 88., 93.]])
# tensor([[185.]])
# Epoch 3/20 Cost: 3.0617523193359375
# tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]])
# tensor([[180.],
#         [196.]])
# Epoch 4/20 Cost: 3.067507266998291
# tensor([[73., 66., 70.],
#         [73., 80., 75.]])
# tensor([[142.],
#         [152.]])
# Epoch 4/20 Cost: 4.10390043258667
# tensor([[93., 88., 93.]])
# tensor([[185.]])
# Epoch 4/20 Cost: 1.5600214004516602
# tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]])
# tensor([[196.],
#         [180.]])
# Epoch 5/20 Cost: 4.005212783813477
# tensor([[93., 88., 93.],
#         [73., 66., 70.]])
# tensor([[185.],
#         [142.]])
# Epoch 5/20 Cost: 5.161328315734863
# tensor([[73., 80., 75.]])
# tensor([[152.]])
# Epoch 5/20 Cost: 1.1740961074829102
# tensor([[73., 66., 70.],
#         [73., 80., 75.]])
# tensor([[142.],
#         [152.]])
# Epoch 6/20 Cost: 3.1174566745758057
# tensor([[89., 91., 90.],
#         [93., 88., 93.]])
# tensor([[180.],
#         [185.]])
# Epoch 6/20 Cost: 1.113741397857666
# tensor([[ 96.,  98., 100.]])
# tensor([[196.]])
# Epoch 6/20 Cost: 4.401442050933838
# tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]])
# tensor([[196.],
#         [152.]])
# Epoch 7/20 Cost: 0.3962499499320984
# tensor([[73., 66., 70.],
#         [93., 88., 93.]])
# tensor([[142.],
#         [185.]])
# Epoch 7/20 Cost: 7.93628454208374
# tensor([[89., 91., 90.]])
# tensor([[180.]])
# Epoch 7/20 Cost: 0.9692344665527344
# tensor([[73., 80., 75.],
#         [73., 66., 70.]])
# tensor([[152.],
#         [142.]])
# Epoch 8/20 Cost: 3.760592222213745
# tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]])
# tensor([[196.],
#         [185.]])
# Epoch 8/20 Cost: 2.412456750869751
# tensor([[89., 91., 90.]])
# tensor([[180.]])
# Epoch 8/20 Cost: 0.5265414118766785
# tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]])
# tensor([[196.],
#         [185.]])
# Epoch 9/20 Cost: 2.255270004272461
# tensor([[73., 80., 75.],
#         [89., 91., 90.]])
# tensor([[152.],
#         [180.]])
# Epoch 9/20 Cost: 0.15335826575756073
# tensor([[73., 66., 70.]])
# tensor([[142.]])
# Epoch 9/20 Cost: 8.345747947692871
# tensor([[73., 66., 70.],
#         [89., 91., 90.]])
# tensor([[142.],
#         [180.]])
# Epoch 10/20 Cost: 3.0348997116088867
# tensor([[73., 80., 75.],
#         [93., 88., 93.]])
# tensor([[152.],
#         [185.]])
# Epoch 10/20 Cost: 0.8306161761283875
# tensor([[ 96.,  98., 100.]])
# tensor([[196.]])
# Epoch 10/20 Cost: 5.413276672363281
# tensor([[89., 91., 90.],
#         [73., 80., 75.]])
# tensor([[180.],
#         [152.]])
# Epoch 11/20 Cost: 0.007411587052047253
# tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]])
# tensor([[196.],
#         [142.]])
# Epoch 11/20 Cost: 5.068782806396484
# tensor([[93., 88., 93.]])
# tensor([[185.]])
# Epoch 11/20 Cost: 2.7891488075256348
# tensor([[73., 66., 70.],
#         [89., 91., 90.]])
# tensor([[142.],
#         [180.]])
# Epoch 12/20 Cost: 3.073488235473633
# tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]])
# tensor([[152.],
#         [196.]])
# Epoch 12/20 Cost: 3.2121376991271973
# tensor([[93., 88., 93.]])
# tensor([[185.]])
# Epoch 12/20 Cost: 2.443934202194214
# tensor([[73., 80., 75.],
#         [89., 91., 90.]])
# tensor([[152.],
#         [180.]])
# Epoch 13/20 Cost: 1.3182036876678467
# tensor([[73., 66., 70.],
#         [93., 88., 93.]])
# tensor([[142.],
#         [185.]])
# Epoch 13/20 Cost: 3.999216318130493
# tensor([[ 96.,  98., 100.]])
# tensor([[196.]])
# Epoch 13/20 Cost: 6.51692008972168
# tensor([[73., 80., 75.],
#         [89., 91., 90.]])
# tensor([[152.],
#         [180.]])
# Epoch 14/20 Cost: 0.025598039850592613
# tensor([[73., 66., 70.],
#         [93., 88., 93.]])
# tensor([[142.],
#         [185.]])
# Epoch 14/20 Cost: 6.358425617218018
# tensor([[ 96.,  98., 100.]])
# tensor([[196.]])
# Epoch 14/20 Cost: 4.579074859619141
# tensor([[93., 88., 93.],
#         [73., 80., 75.]])
# tensor([[185.],
#         [152.]])
# Epoch 15/20 Cost: 2.0621654987335205
# tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]])
# tensor([[196.],
#         [180.]])
# Epoch 15/20 Cost: 1.2250832319259644
# tensor([[73., 66., 70.]])
# tensor([[142.]])
# Epoch 15/20 Cost: 9.433753967285156
# tensor([[73., 66., 70.],
#         [73., 80., 75.]])
# tensor([[142.],
#         [152.]])
# Epoch 16/20 Cost: 2.785245895385742
# tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]])
# tensor([[180.],
#         [196.]])
# Epoch 16/20 Cost: 3.85734224319458
# tensor([[93., 88., 93.]])
# tensor([[185.]])
# Epoch 16/20 Cost: 2.668468952178955
# tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]])
# tensor([[152.],
#         [196.]])
# Epoch 17/20 Cost: 2.8915510177612305
# tensor([[89., 91., 90.],
#         [93., 88., 93.]])
# tensor([[180.],
#         [185.]])
# Epoch 17/20 Cost: 1.3973356485366821
# tensor([[73., 66., 70.]])
# tensor([[142.]])
# Epoch 17/20 Cost: 6.337815284729004
# tensor([[73., 80., 75.],
#         [89., 91., 90.]])
# tensor([[152.],
#         [180.]])
# Epoch 18/20 Cost: 2.323782444000244
# tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]])
# tensor([[196.],
#         [185.]])
# Epoch 18/20 Cost: 2.455160140991211
# tensor([[73., 66., 70.]])
# tensor([[142.]])
# Epoch 18/20 Cost: 6.3087310791015625
# tensor([[93., 88., 93.],
#         [73., 66., 70.]])
# tensor([[185.],
#         [142.]])
# Epoch 19/20 Cost: 1.6443382501602173
# tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]])
# tensor([[152.],
#         [196.]])
# Epoch 19/20 Cost: 6.417860984802246
# tensor([[89., 91., 90.]])
# tensor([[180.]])
# Epoch 19/20 Cost: 0.8692625761032104
# tensor([[73., 80., 75.],
#         [93., 88., 93.]])
# tensor([[152.],
#         [185.]])
# Epoch 20/20 Cost: 1.301720380783081
# tensor([[89., 91., 90.],
#         [73., 66., 70.]])
# tensor([[180.],
#         [142.]])
# Epoch 20/20 Cost: 3.3615031242370605
# tensor([[ 96.,  98., 100.]])
# tensor([[196.]])
# Epoch 20/20 Cost: 4.096090316772461

# %%
new_var = torch.FloatTensor([[73, 80, 75]])
pred_y = model(new_var)
print('훈련 후 입력이 73, 80, 75 일 때의 예측값: ', pred_y.item())
# Out:
# 훈련 후 입력이 73, 80, 75 일 때의 예측값:  154.84690856933594
